# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# ## Variables distribiutions and correlations

# %%
df[df.columns.to_list()[1:-2]].boxplot(rot=45,figsize=(20,20))

# %%
for index,i in enumerate(df.columns.to_list()[1:]):
    plt.figure()
    fig,(ax1,ax2) = plt.subplots(1,2,figsize=(16,5))
    sns.violinplot(df[i][df['Class'] == 0],ax=ax1).set_title('No fraud')
    sns.violinplot(df[i][df['Class'] == 1],ax=ax2).set_title('Fraud')
    plt.show()

# %%
sns.countplot(df['Class']).set_title('Class counts')
# Out:
# Text(0.5, 1.0, 'Class counts')

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,8))

sns.boxplot(ax=ax1,x='Class',y='Amount',data=df,hue='Class',showfliers=True)
sns.boxplot(ax=ax2,x='Class',y='Amount',data=df,hue='Class',showfliers=False)
plt.show()

# %%
class_0 = df.query('Class == 0')['Time']
class_1 = df.query('Class == 1')['Time']

hist_data = [class_0,class_1]
names = ['Not fraud','Fraud']

fig = ff.create_distplot(hist_data,names,show_hist=False, show_rug=False)
fig['layout'].update(title='Credit Card Transactions Time Density Plot', xaxis=dict(title='Time [s]'))
iplot(fig, filename='dist_only')
# Out:
# <div>
#
#
#             <div id="68673531-7f76-4289-b982-3feef6de6d73" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("68673531-7f76-4289-b982-3feef6de6d73")) {
#                     Plotly.newPlot(
#                         '68673531-7f76-4289-b982-3feef6de6d73',
# ...

# %%
plt.subplots(1,1,figsize=(20,20))
sns.heatmap(df.corr(),linewidths=.1,cmap="RdYlBu")

# %% [markdown]
# ### plot corelated variables

# %%
sns.lmplot(x='V2',y='Amount',data=df,hue='Class',fit_reg=True,scatter_kws={'s':2})
sns.lmplot(x='V5',y='Amount',data=df,hue='Class',fit_reg=True,scatter_kws={'s':2})
plt.show()

# %%
sns.lmplot(x='V7',y='Amount',data=df,hue='Class',fit_reg=True,scatter_kws={'s':2})
sns.lmplot(x='V20',y='Amount',data=df,hue='Class',fit_reg=True,scatter_kws={'s':2})
plt.show()
